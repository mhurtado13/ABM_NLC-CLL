# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load experimental data

# %%
experimental = np.loadtxt('../../Netlogo_NLCs-CLL/filtered_fused_9patients.csv', delimiter=",", skiprows=1)
viability_exp = experimental[:,1]
concentration_exp = experimental[:,2]
time_points = experimental[:,0]

# %% [markdown]
# ##### Load output from simulation

# %%
viability_data = pd.read_csv('../data_output/Param_exploration/viability.csv', delimiter=",")
concentration_data = pd.read_csv('../data_output/Param_exploration/concentration.csv', delimiter=",")

# %% [markdown]
# #### Uptake rate cancer

# %%
param_name = "uptake_rate_cancer"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,0:6]
concentration = concentration_data.iloc[:,0:6]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %% [markdown]
# #### Speed cancer

# %%
param_name = "speed_cancer"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,6:12]
concentration = concentration_data.iloc[:,6:12]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "transformation_rate_cancer"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,12:18]
concentration = concentration_data.iloc[:,12:18]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_monocytes"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,18:24]
concentration = concentration_data.iloc[:,18:24]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_monocytes"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,24:30]
concentration = concentration_data.iloc[:,24:30]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_macrophages"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,30:36]
concentration = concentration_data.iloc[:,30:36]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_macrophages"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,36:42]
concentration = concentration_data.iloc[:,36:42]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "secretion_rate_NLCs"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,42:48]
concentration = concentration_data.iloc[:,42:48]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "speed_NLCs"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,48:54]
concentration = concentration_data.iloc[:,48:54]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

# %%
param_name = "dead_phagocytosis_rate_NLCs"
vals = [0, 2, 3, 5, 7, 9]
viability = viability_data.iloc[:,54:60]
concentration = concentration_data.iloc[:,54:60]

### Viability

# Iterate over each column of the matrix
for i in range(viability.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, viability.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, viability_exp, label='Experimental', color = 'black')
plt.xlabel('Time')
plt.ylabel('Viability')
plt.title(f'Viability: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()

###Concentration

# Iterate over each column of the matrix
for i in range(concentration.shape[1]):
    # Plot each column as a separate line, using a different color for each line
    plt.plot(time_points, concentration.iloc[:, i], label=f'Value = {vals[i]}')

plt.plot(time_points, concentration_exp, label='Experimental', color = 'black')
# Add labels and legend
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title(f'Concentration: {param_name}')
plt.legend(loc='upper right', bbox_to_anchor=(1.35, 0.5))

plt.grid(True)
plt.show()
